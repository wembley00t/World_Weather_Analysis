# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather ["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | maragogi
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | sitka
# Processing Record 14 of Set 1 | paamiut
# Processing Record 15 of Set 1 | port-gentil
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | ketchikan
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | ayr
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | hualmay
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | puerto quijarro
# Processing Record 27 of Set 1 | port blair
# Processing Record 28 of Set 1 | mahibadhoo
# Processing Record 29 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 1 | hovd
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | acapulco
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | velingara
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | pochutla
# Processing Record 39 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 1 | tuatapere
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | clinton
# Processing Record 44 of Set 1 | hamilton
# Processing Record 45 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | lalomanu
# City not found. Skipping...
# Processing Record 48 of Set 1 | mawlaik
# Processing Record 49 of Set 1 | itacare
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | srednekolymsk
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | telfs
# Processing Record 4 of Set 2 | kruisfontein
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | tautira
# Processing Record 8 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 2 | cozumel
# Processing Record 10 of Set 2 | usta muhammad
# Processing Record 11 of Set 2 | rawson
# Processing Record 12 of Set 2 | oktyabrskoye
# Processing Record 13 of Set 2 | sorland
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | champerico
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | shigony
# Processing Record 18 of Set 2 | mecca
# Processing Record 19 of Set 2 | ancud
# Processing Record 20 of Set 2 | bijie
# Processing Record 21 of Set 2 | dharmabad
# Processing Record 22 of Set 2 | revda
# Processing Record 23 of Set 2 | los llanos de aridane
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | nishihara
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | kushmurun
# Processing Record 29 of Set 2 | taoudenni
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | kahului
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | leningradskiy
# Processing Record 35 of Set 2 | port hedland
# Processing Record 36 of Set 2 | shangzhi
# Processing Record 37 of Set 2 | busselton
# Processing Record 38 of Set 2 | sisimiut
# Processing Record 39 of Set 2 | bluff
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | tocopilla
# Processing Record 42 of Set 2 | lingao
# Processing Record 43 of Set 2 | revelstoke
# Processing Record 44 of Set 2 | esperance
# Processing Record 45 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | umm lajj
# Processing Record 48 of Set 2 | sterling
# Processing Record 49 of Set 2 | husavik
# Processing Record 50 of Set 2 | bubaque
# Processing Record 1 of Set 3 | zhigansk
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | rongcheng
# Processing Record 6 of Set 3 | lejanias
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | kolo
# Processing Record 10 of Set 3 | mkushi
# Processing Record 11 of Set 3 | merauke
# Processing Record 12 of Set 3 | puksoozero
# Processing Record 13 of Set 3 | huilong
# Processing Record 14 of Set 3 | arlit
# Processing Record 15 of Set 3 | shahr-e babak
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | sibolga
# Processing Record 18 of Set 3 | orlik
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | oksfjord
# Processing Record 21 of Set 3 | hofn
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 3 | halifax
# Processing Record 25 of Set 3 | alghero
# Processing Record 26 of Set 3 | swellendam
# Processing Record 27 of Set 3 | pevek
# Processing Record 28 of Set 3 | new norfolk
# Processing Record 29 of Set 3 | kodiak
# Processing Record 30 of Set 3 | tsybuliv
# Processing Record 31 of Set 3 | fortuna
# Processing Record 32 of Set 3 | saskylakh
# Processing Record 33 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 3 | ust-tarka
# Processing Record 35 of Set 3 | deputatskiy
# Processing Record 36 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 38 of Set 3 | yatou
# Processing Record 39 of Set 3 | palembang
# Processing Record 40 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 3 | rio grande
# Processing Record 42 of Set 3 | vikindu
# Processing Record 43 of Set 3 | korla
# Processing Record 44 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 45 of Set 3 | la ronge
# Processing Record 46 of Set 3 | fairbanks
# Processing Record 47 of Set 3 | riyadh
# Processing Record 48 of Set 3 | coquimbo
# Processing Record 49 of Set 3 | kavaratti
# Processing Record 50 of Set 3 | konstantinovka
# Processing Record 1 of Set 4 | si bun ruang
# Processing Record 2 of Set 4 | victoria
# Processing Record 3 of Set 4 | baykit
# Processing Record 4 of Set 4 | le port
# Processing Record 5 of Set 4 | cururupu
# Processing Record 6 of Set 4 | severo-kurilsk
# Processing Record 7 of Set 4 | ahuimanu
# Processing Record 8 of Set 4 | tigil
# Processing Record 9 of Set 4 | san quintin
# Processing Record 10 of Set 4 | port said
# Processing Record 11 of Set 4 | tasiilaq
# Processing Record 12 of Set 4 | lompoc
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | poso
# Processing Record 15 of Set 4 | moussoro
# Processing Record 16 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 4 | seoul
# Processing Record 18 of Set 4 | clyde river
# Processing Record 19 of Set 4 | margate
# Processing Record 20 of Set 4 | hasaki
# Processing Record 21 of Set 4 | muroto
# Processing Record 22 of Set 4 | siparia
# Processing Record 23 of Set 4 | jalu
# Processing Record 24 of Set 4 | san cristobal
# Processing Record 25 of Set 4 | narang
# Processing Record 26 of Set 4 | neiafu
# Processing Record 27 of Set 4 | naze
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | bethel
# Processing Record 30 of Set 4 | tuktoyaktuk
# Processing Record 31 of Set 4 | oranjemund
# Processing Record 32 of Set 4 | omboue
# Processing Record 33 of Set 4 | maceio
# Processing Record 34 of Set 4 | baishishan
# Processing Record 35 of Set 4 | kalianget
# Processing Record 36 of Set 4 | cabra
# Processing Record 37 of Set 4 | sola
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | santa cruz cabralia
# Processing Record 40 of Set 4 | bodden town
# Processing Record 41 of Set 4 | yima
# Processing Record 42 of Set 4 | nabire
# Processing Record 43 of Set 4 | inuvik
# Processing Record 44 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 45 of Set 4 | lundazi
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | batticaloa
# Processing Record 48 of Set 4 | durant
# Processing Record 49 of Set 4 | berlevag
# Processing Record 50 of Set 4 | kachiry
# Processing Record 1 of Set 5 | banjar
# Processing Record 2 of Set 5 | lavrentiya
# Processing Record 3 of Set 5 | codrington
# Processing Record 4 of Set 5 | leopold
# Processing Record 5 of Set 5 | opuwo
# Processing Record 6 of Set 5 | saint-leu
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | petropavl
# Processing Record 9 of Set 5 | senanga
# Processing Record 10 of Set 5 | mabaruma
# Processing Record 11 of Set 5 | nam tha
# City not found. Skipping...
# Processing Record 12 of Set 5 | santa cruz
# Processing Record 13 of Set 5 | gobabis
# Processing Record 14 of Set 5 | ostrovnoy
# Processing Record 15 of Set 5 | binga
# Processing Record 16 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 5 | cabo san lucas
# Processing Record 18 of Set 5 | beira
# Processing Record 19 of Set 5 | hambantota
# Processing Record 20 of Set 5 | inta
# Processing Record 21 of Set 5 | owo
# Processing Record 22 of Set 5 | suhbaatar
# Processing Record 23 of Set 5 | san patricio
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | markala
# Processing Record 26 of Set 5 | hauterive
# Processing Record 27 of Set 5 | mount hagen
# Processing Record 28 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 5 | cabedelo
# Processing Record 30 of Set 5 | ormara
# Processing Record 31 of Set 5 | yulara
# Processing Record 32 of Set 5 | zyryanka
# Processing Record 33 of Set 5 | kavieng
# Processing Record 34 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 5 | surgut
# Processing Record 36 of Set 5 | pasni
# Processing Record 37 of Set 5 | samarai
# Processing Record 38 of Set 5 | lasa
# Processing Record 39 of Set 5 | kalach-na-donu
# Processing Record 40 of Set 5 | liepaja
# Processing Record 41 of Set 5 | shakiso
# Processing Record 42 of Set 5 | santa rosa
# Processing Record 43 of Set 5 | koceljeva
# Processing Record 44 of Set 5 | arman
# Processing Record 45 of Set 5 | jarva-jaani
# Processing Record 46 of Set 5 | avezzano
# Processing Record 47 of Set 5 | dingle
# Processing Record 48 of Set 5 | tateyama
# Processing Record 49 of Set 5 | soyo
# Processing Record 50 of Set 5 | abu samrah
# Processing Record 1 of Set 6 | ponta delgada
# Processing Record 2 of Set 6 | derzhavinsk
# Processing Record 3 of Set 6 | fort nelson
# Processing Record 4 of Set 6 | ribeira grande
# Processing Record 5 of Set 6 | xai-xai
# Processing Record 6 of Set 6 | nikolskoye
# Processing Record 7 of Set 6 | sechura
# Processing Record 8 of Set 6 | mina
# Processing Record 9 of Set 6 | kermanshah
# Processing Record 10 of Set 6 | goderich
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | norman wells
# Processing Record 13 of Set 6 | ginir
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | acajutla
# Processing Record 16 of Set 6 | ambon
# Processing Record 17 of Set 6 | poum
# Processing Record 18 of Set 6 | channel-port aux basques
# Processing Record 19 of Set 6 | aklavik
# Processing Record 20 of Set 6 | bathsheba
# Processing Record 21 of Set 6 | las vegas
# Processing Record 22 of Set 6 | tabou
# Processing Record 23 of Set 6 | yinchuan
# Processing Record 24 of Set 6 | gigmoto
# Processing Record 25 of Set 6 | cherskiy
# Processing Record 26 of Set 6 | dargaville
# Processing Record 27 of Set 6 | queimadas
# Processing Record 28 of Set 6 | yerbogachen
# Processing Record 29 of Set 6 | kondinskoye
# Processing Record 30 of Set 6 | grindavik
# Processing Record 31 of Set 6 | evensk
# Processing Record 32 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 6 | den helder
# Processing Record 34 of Set 6 | pangnirtung
# Processing Record 35 of Set 6 | sambava
# Processing Record 36 of Set 6 | bagaha
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | bergerac
# Processing Record 39 of Set 6 | henderson
# Processing Record 40 of Set 6 | kizilskoye
# Processing Record 41 of Set 6 | sao filipe
# Processing Record 42 of Set 6 | san pedro
# Processing Record 43 of Set 6 | vanavara
# Processing Record 44 of Set 6 | jaciara
# Processing Record 45 of Set 6 | mafinga
# Processing Record 46 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 6 | kolyvan
# Processing Record 48 of Set 6 | boende
# Processing Record 49 of Set 6 | labuhan
# Processing Record 50 of Set 6 | stokmarknes
# Processing Record 1 of Set 7 | pacific grove
# Processing Record 2 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 7 | stephenville
# Processing Record 4 of Set 7 | mehamn
# Processing Record 5 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 7 | gamboma
# Processing Record 7 of Set 7 | constitucion
# Processing Record 8 of Set 7 | rafsanjan
# Processing Record 9 of Set 7 | marienburg
# Processing Record 10 of Set 7 | broken hill
# Processing Record 11 of Set 7 | eichstatt
# Processing Record 12 of Set 7 | kortkeros
# Processing Record 13 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 14 of Set 7 | trbovlje
# Processing Record 15 of Set 7 | beringovskiy
# Processing Record 16 of Set 7 | pandan
# Processing Record 17 of Set 7 | shirokiy
# Processing Record 18 of Set 7 | avera
# Processing Record 19 of Set 7 | cockburn town
# Processing Record 20 of Set 7 | praia da vitoria
# Processing Record 21 of Set 7 | isilkul
# Processing Record 22 of Set 7 | sonamukhi
# Processing Record 23 of Set 7 | kulhudhuffushi
# Processing Record 24 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 7 | charters towers
# Processing Record 26 of Set 7 | aswan
# Processing Record 27 of Set 7 | sydney
# Processing Record 28 of Set 7 | serenje
# Processing Record 29 of Set 7 | vysokogornyy
# Processing Record 30 of Set 7 | reconquista
# Processing Record 31 of Set 7 | talnakh
# Processing Record 32 of Set 7 | dunmore town
# Processing Record 33 of Set 7 | les cayes
# Processing Record 34 of Set 7 | udachnyy
# Processing Record 35 of Set 7 | lagoa
# Processing Record 36 of Set 7 | caravelas
# Processing Record 37 of Set 7 | vestmannaeyjar
# Processing Record 38 of Set 7 | ilebo
# Processing Record 39 of Set 7 | prince rupert
# Processing Record 40 of Set 7 | smithers
# Processing Record 41 of Set 7 | tessalit
# Processing Record 42 of Set 7 | deniliquin
# Processing Record 43 of Set 7 | xining
# Processing Record 44 of Set 7 | lumajang
# Processing Record 45 of Set 7 | san jose
# Processing Record 46 of Set 7 | torbay
# Processing Record 47 of Set 7 | santa vitoria
# Processing Record 48 of Set 7 | kem
# Processing Record 49 of Set 7 | kitimat
# Processing Record 50 of Set 7 | lata
# Processing Record 1 of Set 8 | pangoa
# Processing Record 2 of Set 8 | luderitz
# Processing Record 3 of Set 8 | xuanhua
# Processing Record 4 of Set 8 | kaeo
# Processing Record 5 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 8 | lebork
# Processing Record 7 of Set 8 | ginda
# Processing Record 8 of Set 8 | palmer
# Processing Record 9 of Set 8 | sabancuy
# Processing Record 10 of Set 8 | buchanan
# Processing Record 11 of Set 8 | yazoo city
# Processing Record 12 of Set 8 | saryg-sep
# Processing Record 13 of Set 8 | gogrial
# Processing Record 14 of Set 8 | caucaia
# Processing Record 15 of Set 8 | blagoyevo
# Processing Record 16 of Set 8 | sokoni
# Processing Record 17 of Set 8 | palmerston
# Processing Record 18 of Set 8 | cidreira
# Processing Record 19 of Set 8 | puerto escondido
# Processing Record 20 of Set 8 | boyolangu
# Processing Record 21 of Set 8 | chom bung
# City not found. Skipping...
# Processing Record 22 of Set 8 | talcahuano
# Processing Record 23 of Set 8 | turbat
# Processing Record 24 of Set 8 | briceni
# Processing Record 25 of Set 8 | sioux lookout
# Processing Record 26 of Set 8 | ust-nera
# Processing Record 27 of Set 8 | narsaq
# Processing Record 28 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 29 of Set 8 | muscat
# Processing Record 30 of Set 8 | quatre cocos
# Processing Record 31 of Set 8 | girne
# Processing Record 32 of Set 8 | nanortalik
# Processing Record 33 of Set 8 | navoi
# Processing Record 34 of Set 8 | fenelon falls
# Processing Record 35 of Set 8 | skibbereen
# Processing Record 36 of Set 8 | guerrero negro
# Processing Record 37 of Set 8 | amapa
# Processing Record 38 of Set 8 | farsund
# Processing Record 39 of Set 8 | aksarka
# Processing Record 40 of Set 8 | dalbandin
# Processing Record 41 of Set 8 | marawi
# Processing Record 42 of Set 8 | ukiah
# Processing Record 43 of Set 8 | santiago del estero
# Processing Record 44 of Set 8 | la seyne-sur-mer
# Processing Record 45 of Set 8 | tacuati
# Processing Record 46 of Set 8 | port lincoln
# Processing Record 47 of Set 8 | kijang
# Processing Record 48 of Set 8 | souillac
# Processing Record 49 of Set 8 | ambilobe
# Processing Record 50 of Set 8 | boa vista
# Processing Record 1 of Set 9 | valparaiso
# Processing Record 2 of Set 9 | amboasary
# Processing Record 3 of Set 9 | biltine
# Processing Record 4 of Set 9 | adrar
# Processing Record 5 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 9 | georgetown
# Processing Record 7 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 9 | zhezkazgan
# Processing Record 9 of Set 9 | saint-augustin
# Processing Record 10 of Set 9 | balakhta
# Processing Record 11 of Set 9 | airai
# Processing Record 12 of Set 9 | bluefields
# Processing Record 13 of Set 9 | dingzhou
# Processing Record 14 of Set 9 | kentau
# Processing Record 15 of Set 9 | komsomolskiy
# Processing Record 16 of Set 9 | hervey bay
# Processing Record 17 of Set 9 | guntakal
# Processing Record 18 of Set 9 | inongo
# Processing Record 19 of Set 9 | taltal
# Processing Record 20 of Set 9 | esmeralda
# Processing Record 21 of Set 9 | trinidad
# Processing Record 22 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 9 | scottsbluff
# Processing Record 24 of Set 9 | atar
# Processing Record 25 of Set 9 | salalah
# Processing Record 26 of Set 9 | bac lieu
# Processing Record 27 of Set 9 | babanka
# Processing Record 28 of Set 9 | vitim
# Processing Record 29 of Set 9 | iqaluit
# Processing Record 30 of Set 9 | fare
# Processing Record 31 of Set 9 | salinopolis
# Processing Record 32 of Set 9 | alofi
# Processing Record 33 of Set 9 | jibuti
# Processing Record 34 of Set 9 | hakkari
# Processing Record 35 of Set 9 | madison
# Processing Record 36 of Set 9 | sao joao do paraiso
# Processing Record 37 of Set 9 | vung tau
# Processing Record 38 of Set 9 | khovu-aksy
# Processing Record 39 of Set 9 | tabukiniberu
# City not found. Skipping...
# Processing Record 40 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 9 | hobyo
# Processing Record 42 of Set 9 | tazovskiy
# Processing Record 43 of Set 9 | bilibino
# Processing Record 44 of Set 9 | kununurra
# Processing Record 45 of Set 9 | tarko-sale
# Processing Record 46 of Set 9 | mogadishu
# Processing Record 47 of Set 9 | puerto del rosario
# Processing Record 48 of Set 9 | henties bay
# Processing Record 49 of Set 9 | sungaipenuh
# Processing Record 50 of Set 9 | ixtapa
# Processing Record 1 of Set 10 | klaksvik
# Processing Record 2 of Set 10 | mandalgovi
# Processing Record 3 of Set 10 | montepuez
# Processing Record 4 of Set 10 | linqiong
# Processing Record 5 of Set 10 | itarema
# Processing Record 6 of Set 10 | oyama
# Processing Record 7 of Set 10 | pemba
# Processing Record 8 of Set 10 | whitehorse
# Processing Record 9 of Set 10 | biak
# Processing Record 10 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 10 | cartagena
# Processing Record 12 of Set 10 | ati
# Processing Record 13 of Set 10 | fonte boa
# Processing Record 14 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 10 | preobrazheniye
# Processing Record 16 of Set 10 | qui nhon
# Processing Record 17 of Set 10 | marsh harbour
# Processing Record 18 of Set 10 | viedma
# Processing Record 19 of Set 10 | ayan
# Processing Record 20 of Set 10 | cayenne
# Processing Record 21 of Set 10 | tomaszow lubelski
# Processing Record 22 of Set 10 | karsava
# Processing Record 23 of Set 10 | padang
# Processing Record 24 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 10 | sao jose da coroa grande
# Processing Record 26 of Set 10 | san policarpo
# Processing Record 27 of Set 10 | cajati
# Processing Record 28 of Set 10 | bonthe
# Processing Record 29 of Set 10 | strezhevoy
# Processing Record 30 of Set 10 | kupino
# Processing Record 31 of Set 10 | kismayo
# Processing Record 32 of Set 10 | mongo
# Processing Record 33 of Set 10 | karasuk
# Processing Record 34 of Set 10 | chicama
# Processing Record 35 of Set 10 | tupik
# Processing Record 36 of Set 10 | petauke
# Processing Record 37 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 10 | nouadhibou
# Processing Record 39 of Set 10 | pleasanton
# Processing Record 40 of Set 10 | mount gambier
# Processing Record 41 of Set 10 | krasnogorsk
# Processing Record 42 of Set 10 | jawhar
# Processing Record 43 of Set 10 | paragominas
# Processing Record 44 of Set 10 | ilhabela
# Processing Record 45 of Set 10 | muros
# Processing Record 46 of Set 10 | laguna
# Processing Record 47 of Set 10 | dorogobuzh
# Processing Record 48 of Set 10 | shenjiamen
# Processing Record 49 of Set 10 | pita
# Processing Record 50 of Set 10 | visby
# Processing Record 1 of Set 11 | verkhoyansk
# Processing Record 2 of Set 11 | lorengau
# Processing Record 3 of Set 11 | broome
# Processing Record 4 of Set 11 | coachella
# Processing Record 5 of Set 11 | bulgan
# Processing Record 6 of Set 11 | samarkand
# Processing Record 7 of Set 11 | kiunga
# Processing Record 8 of Set 11 | namibe
# Processing Record 9 of Set 11 | emba
# Processing Record 10 of Set 11 | mumford
# Processing Record 11 of Set 11 | kenai
# Processing Record 12 of Set 11 | edson
# Processing Record 13 of Set 11 | kisangani
# Processing Record 14 of Set 11 | yar-sale
# Processing Record 15 of Set 11 | karratha
# Processing Record 16 of Set 11 | stornoway
# Processing Record 17 of Set 11 | surovikino
# Processing Record 18 of Set 11 | cristalina
# Processing Record 19 of Set 11 | rincon
# Processing Record 20 of Set 11 | carlyle
# Processing Record 21 of Set 11 | marfino
# Processing Record 22 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 23 of Set 11 | severodvinsk
# Processing Record 24 of Set 11 | susangerd
# Processing Record 25 of Set 11 | noyon
# Processing Record 26 of Set 11 | alta floresta
# Processing Record 27 of Set 11 | carballo
# Processing Record 28 of Set 11 | eyl
# Processing Record 29 of Set 11 | baruun-urt
# Processing Record 30 of Set 11 | paradise
# Processing Record 31 of Set 11 | nouakchott
# Processing Record 32 of Set 11 | puerto madryn
# Processing Record 33 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 34 of Set 11 | valday
# Processing Record 35 of Set 11 | finschhafen
# Processing Record 36 of Set 11 | humaita
# Processing Record 37 of Set 11 | imbituba
# Processing Record 38 of Set 11 | diamantino
# Processing Record 39 of Set 11 | vila franca do campo
# Processing Record 40 of Set 11 | sembakung
# Processing Record 41 of Set 11 | sinnamary
# Processing Record 42 of Set 11 | caetite
# Processing Record 43 of Set 11 | victor harbor
# Processing Record 44 of Set 11 | roma
# Processing Record 45 of Set 11 | astana
# Processing Record 46 of Set 11 | richards bay
# Processing Record 47 of Set 11 | lodja
# Processing Record 48 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 11 | haines junction
# Processing Record 50 of Set 11 | angoche
# Processing Record 1 of Set 12 | ossora
# Processing Record 2 of Set 12 | vila
# Processing Record 3 of Set 12 | puerto ayacucho
# Processing Record 4 of Set 12 | te anau
# Processing Record 5 of Set 12 | walvis bay
# Processing Record 6 of Set 12 | bucerias
# Processing Record 7 of Set 12 | kifri
# Processing Record 8 of Set 12 | thessalon
# Processing Record 9 of Set 12 | tomatlan
# Processing Record 10 of Set 12 | chanika
# Processing Record 11 of Set 12 | teknaf
# Processing Record 12 of Set 12 | port keats
# Processing Record 13 of Set 12 | talaya
# Processing Record 14 of Set 12 | half moon bay
# Processing Record 15 of Set 12 | mezen
# Processing Record 16 of Set 12 | laiagam
# City not found. Skipping...
# Processing Record 17 of Set 12 | buribay
# Processing Record 18 of Set 12 | cornwall
# Processing Record 19 of Set 12 | vesyegonsk
# Processing Record 20 of Set 12 | daru
# Processing Record 21 of Set 12 | porto novo
# Processing Record 22 of Set 12 | monrovia
# Processing Record 23 of Set 12 | cascais
# Processing Record 24 of Set 12 | maryville
# Processing Record 25 of Set 12 | karasjok
# Processing Record 26 of Set 12 | guymon
# Processing Record 27 of Set 12 | dunedin
# Processing Record 28 of Set 12 | guapi
# Processing Record 29 of Set 12 | coxim
# Processing Record 30 of Set 12 | port macquarie
# Processing Record 31 of Set 12 | nome
# Processing Record 32 of Set 12 | chara
# Processing Record 33 of Set 12 | lamu
# Processing Record 34 of Set 12 | paracuru
# Processing Record 35 of Set 12 | sao joao da barra
# Processing Record 36 of Set 12 | beyneu
# Processing Record 37 of Set 12 | sol-iletsk
# Processing Record 38 of Set 12 | concordia
# Processing Record 39 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 12 | coahuayana
# Processing Record 41 of Set 12 | juneau
# Processing Record 42 of Set 12 | cabaiguan
# Processing Record 43 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 12 | ekhabi
# Processing Record 45 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 12 | laem sing
# Processing Record 47 of Set 12 | iquitos
# Processing Record 48 of Set 12 | griffith
# Processing Record 49 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 1 of Set 13 | wanning
# Processing Record 2 of Set 13 | grand baie
# Processing Record 3 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 13 | meulaboh
# Processing Record 5 of Set 13 | okha
# Processing Record 6 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 7 of Set 13 | helena
# Processing Record 8 of Set 13 | sergeyevka
# Processing Record 9 of Set 13 | yumen
# Processing Record 10 of Set 13 | port hardy
# Processing Record 11 of Set 13 | san vicente
# Processing Record 12 of Set 13 | venado tuerto
# Processing Record 13 of Set 13 | yining
# Processing Record 14 of Set 13 | isangel
# Processing Record 15 of Set 13 | ola
# Processing Record 16 of Set 13 | port hawkesbury
# Processing Record 17 of Set 13 | along
# Processing Record 18 of Set 13 | pocone
# Processing Record 19 of Set 13 | kiskunfelegyhaza
# Processing Record 20 of Set 13 | tefe
# Processing Record 21 of Set 13 | moose factory
# Processing Record 22 of Set 13 | zaranj
# Processing Record 23 of Set 13 | nueva guinea
# Processing Record 24 of Set 13 | miquelon
# Processing Record 25 of Set 13 | lerwick
# Processing Record 26 of Set 13 | kishi
# Processing Record 27 of Set 13 | mikhaylovka
# Processing Record 28 of Set 13 | satkhira
# Processing Record 29 of Set 13 | vao
# Processing Record 30 of Set 13 | chumikan
# Processing Record 31 of Set 13 | ankang
# Processing Record 32 of Set 13 | makung
# City not found. Skipping...
# Processing Record 33 of Set 13 | poronaysk
# Processing Record 34 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 13 | petrila
# Processing Record 36 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 37 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 13 | spirit river
# Processing Record 39 of Set 13 | tabory
# Processing Record 40 of Set 13 | faya
# Processing Record 41 of Set 13 | nemuro
# Processing Record 42 of Set 13 | brainerd
# Processing Record 43 of Set 13 | sijunjung
# Processing Record 44 of Set 13 | porbandar
# Processing Record 45 of Set 13 | menongue
# Processing Record 46 of Set 13 | flinders
# Processing Record 47 of Set 13 | la estancia
# Processing Record 48 of Set 13 | verkhnyaya inta
# Processing Record 49 of Set 13 | comodoro rivadavia
# Processing Record 50 of Set 13 | arcachon
# Processing Record 1 of Set 14 | hirara
# Processing Record 2 of Set 14 | guane
# Processing Record 3 of Set 14 | chunskiy
# Processing Record 4 of Set 14 | tingo maria
# Processing Record 5 of Set 14 | lukulu
# Processing Record 6 of Set 14 | angra
# City not found. Skipping...
# Processing Record 7 of Set 14 | karakol
# Processing Record 8 of Set 14 | nandi hills
# Processing Record 9 of Set 14 | purwa
# Processing Record 10 of Set 14 | okhotsk
# Processing Record 11 of Set 14 | macusani
# Processing Record 12 of Set 14 | sayville
# Processing Record 13 of Set 14 | sakaiminato
# Processing Record 14 of Set 14 | altos
# Processing Record 15 of Set 14 | skjaerhollen
# City not found. Skipping...
# Processing Record 16 of Set 14 | jasper
# Processing Record 17 of Set 14 | inhambane
# Processing Record 18 of Set 14 | santa vitoria do palmar
# Processing Record 19 of Set 14 | chuzhou
# Processing Record 20 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 21 of Set 14 | tevaitoa
# Processing Record 22 of Set 14 | lebanon
# Processing Record 23 of Set 14 | samatau
# City not found. Skipping...
# Processing Record 24 of Set 14 | kuito
# Processing Record 25 of Set 14 | katete
# Processing Record 26 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 14 | afgoye
# City not found. Skipping...
# Processing Record 28 of Set 14 | fukue
# Processing Record 29 of Set 14 | the valley
# Processing Record 30 of Set 14 | tura
# Processing Record 31 of Set 14 | upata
# Processing Record 32 of Set 14 | rumphi
# Processing Record 33 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 14 | fremont
# Processing Record 35 of Set 14 | ahipara
# Processing Record 36 of Set 14 | castries
# Processing Record 37 of Set 14 | road town
# Processing Record 38 of Set 14 | trincomalee
# Processing Record 39 of Set 14 | trogir
# Processing Record 40 of Set 14 | jilib
# Processing Record 41 of Set 14 | dasoguz
# Processing Record 42 of Set 14 | vila velha
# Processing Record 43 of Set 14 | rambha
# Processing Record 44 of Set 14 | sobolevo
# Processing Record 45 of Set 14 | vardo
# Processing Record 46 of Set 14 | tezu
# Processing Record 47 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 48 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 14 | flin flon
# Processing Record 50 of Set 14 | alyangula
# Processing Record 1 of Set 15 | shache
# Processing Record 2 of Set 15 | quime
# Processing Record 3 of Set 15 | makakilo city
# Processing Record 4 of Set 15 | sakakah
# Processing Record 5 of Set 15 | placido de castro
# Processing Record 6 of Set 15 | krasnoselkup
# Processing Record 7 of Set 15 | kropotkin
# Processing Record 8 of Set 15 | svetlaya
# Processing Record 9 of Set 15 | cilegon
# Processing Record 10 of Set 15 | osterburg
# Processing Record 11 of Set 15 | kargat
# Processing Record 12 of Set 15 | huicungo
# Processing Record 13 of Set 15 | saint-louis
# Processing Record 14 of Set 15 | synya
# Processing Record 15 of Set 15 | qaqortoq
# Processing Record 16 of Set 15 | urucara
# Processing Record 17 of Set 15 | dumai
# Processing Record 18 of Set 15 | itoman
# Processing Record 19 of Set 15 | bridgetown
# Processing Record 20 of Set 15 | morondava
# Processing Record 21 of Set 15 | new port richey
# Processing Record 22 of Set 15 | sistranda
# Processing Record 23 of Set 15 | sampit
# Processing Record 24 of Set 15 | rypefjord
# Processing Record 25 of Set 15 | kidal
# Processing Record 26 of Set 15 | rocha
# Processing Record 27 of Set 15 | bayan
# Processing Record 28 of Set 15 | maarianhamina
# Processing Record 29 of Set 15 | lima
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 663

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mataura -46.1927  168.8643     52.48        99          29
# 1     Longyearbyen  78.2186   15.6401     15.64        57           0
# 2  Bambous Virieux -20.3428   57.7575     77.25        88          40
# 3         Hermanus -34.4187   19.2345     68.81        74           0
# 4         Khatanga  71.9667  102.5000     16.70        95          99
# 5        Cape Town -33.9258   18.4232     69.12        69           0
# 6             Lebu -37.6167  -73.6500     54.25        73         100
# 7   Port Elizabeth -33.9180   25.5701     67.10        75           0
# 8          Ushuaia -54.8000  -68.3000     47.86        66          75
# 9           Dikson  73.5069   80.5464      8.73        97          35
#
#    Wind Speed Country Current Description
# 0        2.37      NZ    scattered clouds
# 1        8.05      SJ           clear sky
# 2        3.44      MU    scattered clouds
# 3       11.21      ZA           clear sky
# 4        9.60      RU     overcast clouds
# 5       16.11      ZA           clear sky
# 6       13.89      CL     overcast clouds
# 7       12.66      ZA           clear sky
# 8        5.75      AR       broken clouds
# 9        9.86      RU    scattered clouds

# %%
#Re-order the columns:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mataura      NZ -46.1927  168.8643     52.48        99          29
# 1     Longyearbyen      SJ  78.2186   15.6401     15.64        57           0
# 2  Bambous Virieux      MU -20.3428   57.7575     77.25        88          40
# 3         Hermanus      ZA -34.4187   19.2345     68.81        74           0
# 4         Khatanga      RU  71.9667  102.5000     16.70        95          99
#
#    Wind Speed Current Description
# 0        2.37    scattered clouds
# 1        8.05           clear sky
# 2        3.44    scattered clouds
# 3       11.21           clear sky
# 4        9.60     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
